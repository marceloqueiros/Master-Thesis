# 903   27,7545945945946  1,83276204572898   -0,556034706691263
# 904   27,8721126760563  1,83752754027449    0,343058826955845
# 905   29,1754859611231  1,82284899968538    0,852549452457813
# 906   34,8776722090261  1,79038830433253   -0,530290035902954
# 907   26,5467820443483  1,79394927167159   -0,706360903133674
# 908   26,8762573099415  1,82643434062108    -1,22592230650572
# 909    27,074720029374  1,81743470123952   -0,587439884450947
# 910   27,2299725216656  1,83785755870367    0,371050319981618
# 911   41,9420091324201  1,73044974034599  -0,0861907298763097
# 912   42,4247171453438  1,73073004280693    -1,02033833915241
# 913   43,1749044044753  1,72825709018625    0,533372524143013
# 914   41,7823574730354   1,7316480281253   -0,089065629036274
# 915   43,6336245094316  1,72185503478771   -0,476604824054748
# 916   43,8807482462977  1,72217386928128    0,282276072770042
#
#                     DUVOL CRASH_COUNT
# 0       0,185164273783554           1
# 1      -0,357858167322267          -3
# 2       0,266693723092023           1
# 3       0,299989663441262           2
# 4      0,0384242075427948           2
# 5       0,416308452221267           2
# 6      -0,531098071579882          -2
# 7       0,548950260187256           2
# 8       0,267916428380242           2
# 9       0,251152099698228           1
# 10     -0,345126725150636           2
# 11      0,298487608679229           3
# 12   -0,00959904137590591           1
# 13     -0,193379542438099          -3
# 14    -0,0355459471880084           0
# 15     -0,310248783087844          -3
# 16      -0,49162545796033          -2
# 17      0,776615761736074           2
# 18       0,37320077347532           4
# 19     -0,376538387977508          -4
# 20      0,156780010712595           1
# 21      0,307013875638941           2
# 22     -0,113839655213915           0
# 23      0,237998315491232           3
# 24     -0,136118392611716          -1
# 25     -0,449355275928834          -2
# 26     -0,377592485941811          -1
# 27     0,0030270023307597           2
# 28      0,408617193599541           1
# 29     -0,423009798002743           0
# ..                    ...         ...
# 887    -0,106347267322223           2
# 888   -0,0773667445952307           0
# 889   -0,0125952321526549           0
# 890    -0,468207014197865           0
# 891   -0,0240957848179774           2
# 892    -0,326176313821198          -1
# 893   0,00961616424368092           2
# 894     0,242098190687071           2
# 895    -0,144186497352557           2
# 896    -0,293518668264684          -1
# 897    -0,257334908133964          -1
# 898    -0,489585542782063           0
# 899    -0,381235691670974          -1
# 900    0,0660895944476172           1
# 901    -0,111013974138449           0
# 902    -0,395487755323958          -2
# 903   -0,0791979297365282           1
# 904     0,143544895501766           3
# 905     0,439833377016212           1
# 906     -0,28944030515217          -1
# 907     -0,04947124372101           2
# 908    -0,774536778042438          -3
# 909    -0,282588440624295          -2
# 910     0,269610767700178           1
# 911   -0,0959139206801694           1
# 912    -0,579386026345868          -1
# 913     0,193939568586891          -1
# 914    -0,103322731581771           0
# 915   -0,0500049626326772          -2
# 916   -0,0116305704381884           0
#
# [917 rows x 55 columns]

# %% [markdown]
# Extracting training and test dataset

# %%
#dataset = pd.read_csv('../input/salary-data/Salary_Data.csv')
dataset = pd.read_csv("Companies.csv", sep=';', encoding = "ISO-8859-1") # , index_col = 0

X = dataset.iloc[:,].values
y = dataset.iloc[:,1].values

# We are going to keep 20% of the dataset in test dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/5, random_state=0)

# %%
y
# Out:
# array(['3M', '3M', '3M', '3M', '3M', '3M', '3M', '3M', '3M', '3M',
#        'ABBOTT LABORATORIES', 'ABBOTT LABORATORIES',
#        'ABBOTT LABORATORIES', 'ABBOTT LABORATORIES',
#        'ABBOTT LABORATORIES', 'ABBOTT LABORATORIES',
#        'ABBOTT LABORATORIES', 'ABBOTT LABORATORIES',
#        'ABBOTT LABORATORIES', 'ABBOTT LABORATORIES', 'ABBVIE', 'ABBVIE',
#        'ABBVIE', 'ABBVIE', 'ABBVIE', 'ACCENTURE CLASS A',
#        'ACCENTURE CLASS A', 'ACCENTURE CLASS A', 'ACCENTURE CLASS A',
#        'ACCENTURE CLASS A', 'ACCENTURE CLASS A', 'ACCENTURE CLASS A',
#        'ACCENTURE CLASS A', 'ACCENTURE CLASS A', 'ALLERGAN', 'ALLERGAN',
#        'ALLERGAN', 'ALLERGAN', 'ALLSTATE', 'ALLSTATE', 'ALLSTATE',
#        'ALLSTATE', 'ALLSTATE', 'ALLSTATE', 'ALLSTATE', 'ALLSTATE',
#        'ALLSTATE', 'ALLSTATE', "ALPHABET 'C'", "ALPHABET 'C'",
#        'ALPHABET A', 'ALPHABET A', 'ALTRIA GROUP', 'ALTRIA GROUP',
#        'ALTRIA GROUP', 'ALTRIA GROUP', 'ALTRIA GROUP', 'ALTRIA GROUP',
#        'ALTRIA GROUP', 'ALTRIA GROUP', 'ALTRIA GROUP', 'ALTRIA GROUP',
#        'AMAZON.COM', 'AMAZON.COM', 'AMAZON.COM', 'AMAZON.COM',
#        'AMAZON.COM', 'AMAZON.COM', 'AMAZON.COM', 'AMAZON.COM',
#        'AMAZON.COM', 'AMAZON.COM', 'AMERICAN EXPRESS', 'AMERICAN EXPRESS',
#        'AMERICAN EXPRESS', 'AMERICAN EXPRESS', 'AMERICAN EXPRESS',
#        'AMERICAN EXPRESS', 'AMERICAN EXPRESS', 'AMERICAN EXPRESS',
#        'AMERICAN EXPRESS', 'AMERICAN EXPRESS', 'AMERICAN INTL.GP',
#        'AMERICAN INTL.GP', 'AMERICAN INTL.GP', 'AMERICAN INTL.GP',
#        'AMERICAN INTL.GP', 'AMERICAN INTL.GP', 'AMERICAN INTL.GP',
#        'AMERICAN INTL.GP', 'AMERICAN INTL.GP', 'AMERICAN INTL.GP',
#        'AMGEN', 'AMGEN', 'AMGEN', 'AMGEN', 'AMGEN', 'AMGEN', 'AMGEN',
#        'AMGEN', 'AMGEN', 'AMGEN', 'APPLE', 'APPLE', 'APPLE', 'APPLE',
#        'APPLE', 'APPLE', 'APPLE', 'APPLE', 'APPLE', 'APPLE', 'AT&T',
#        'AT&T', 'AT&T', 'AT&T', 'AT&T', 'AT&T', 'AT&T', 'AT&T', 'AT&T',
#        'AT&T', 'BANK OF AMERICA', 'BANK OF AMERICA', 'BANK OF AMERICA',
#        'BANK OF AMERICA', 'BANK OF AMERICA', 'BANK OF AMERICA',
#        'BANK OF AMERICA', 'BANK OF AMERICA', 'BANK OF AMERICA',
#        'BANK OF AMERICA', 'BANK OF NEW YORK MELLON',
#        'BANK OF NEW YORK MELLON', 'BANK OF NEW YORK MELLON',
#        'BANK OF NEW YORK MELLON', 'BANK OF NEW YORK MELLON',
#        'BANK OF NEW YORK MELLON', 'BANK OF NEW YORK MELLON',
#        'BANK OF NEW YORK MELLON', 'BANK OF NEW YORK MELLON',
#        'BANK OF NEW YORK MELLON', "BERKSHIRE HATHAWAY 'B'",
#        "BERKSHIRE HATHAWAY 'B'", "BERKSHIRE HATHAWAY 'B'",
#        "BERKSHIRE HATHAWAY 'B'", "BERKSHIRE HATHAWAY 'B'",
#        "BERKSHIRE HATHAWAY 'B'", "BERKSHIRE HATHAWAY 'B'",
#        "BERKSHIRE HATHAWAY 'B'", "BERKSHIRE HATHAWAY 'B'",
#        "BERKSHIRE HATHAWAY 'B'", 'BIOGEN', 'BIOGEN', 'BIOGEN', 'BIOGEN',
#        'BIOGEN', 'BIOGEN', 'BIOGEN', 'BIOGEN', 'BIOGEN', 'BIOGEN',
#        'BLACKROCK', 'BLACKROCK', 'BLACKROCK', 'BLACKROCK', 'BLACKROCK',
#        'BLACKROCK', 'BLACKROCK', 'BLACKROCK', 'BLACKROCK', 'BLACKROCK',
#        'BOEING', 'BOEING', 'BOEING', 'BOEING', 'BOEING', 'BOEING',
#        'BOEING', 'BOEING', 'BOEING', 'BOEING', 'BOOKING HOLDINGS',
#        'BOOKING HOLDINGS', 'BOOKING HOLDINGS', 'BOOKING HOLDINGS',
#        'BOOKING HOLDINGS', 'BOOKING HOLDINGS', 'BOOKING HOLDINGS',
#        'BOOKING HOLDINGS', 'BOOKING HOLDINGS', 'BOOKING HOLDINGS',
#        'BRISTOL MYERS SQUIBB', 'BRISTOL MYERS SQUIBB',
#        'BRISTOL MYERS SQUIBB', 'BRISTOL MYERS SQUIBB',
#        'BRISTOL MYERS SQUIBB', 'BRISTOL MYERS SQUIBB',
#        'BRISTOL MYERS SQUIBB', 'BRISTOL MYERS SQUIBB',
#        'BRISTOL MYERS SQUIBB', 'BRISTOL MYERS SQUIBB', 'CAPITAL ONE FINL',
#        'CAPITAL ONE FINL', 'CAPITAL ONE FINL', 'CAPITAL ONE FINL',
#        'CAPITAL ONE FINL', 'CAPITAL ONE FINL', 'CAPITAL ONE FINL',
#        'CAPITAL ONE FINL', 'CAPITAL ONE FINL', 'CAPITAL ONE FINL',
#        'CATERPILLAR', 'CATERPILLAR', 'CATERPILLAR', 'CATERPILLAR',
#        'CATERPILLAR', 'CATERPILLAR', 'CATERPILLAR', 'CATERPILLAR',
#        'CATERPILLAR', 'CATERPILLAR', 'CELGENE', 'CELGENE', 'CELGENE',
#        'CELGENE', 'CELGENE', 'CELGENE', 'CELGENE', 'CELGENE', 'CELGENE',
#        'CELGENE', 'CHARTER COMMS.CL.A', 'CHARTER COMMS.CL.A',
#        'CHARTER COMMS.CL.A', 'CHARTER COMMS.CL.A', 'CHARTER COMMS.CL.A',
#        'CHARTER COMMS.CL.A', 'CHARTER COMMS.CL.A', 'CHEVRON', 'CHEVRON',
#        'CHEVRON', 'CHEVRON', 'CHEVRON', 'CHEVRON', 'CHEVRON', 'CHEVRON',
#        'CHEVRON', 'CHEVRON', 'CISCO SYSTEMS', 'CISCO SYSTEMS',
#        'CISCO SYSTEMS', 'CISCO SYSTEMS', 'CISCO SYSTEMS', 'CISCO SYSTEMS',
#        'CISCO SYSTEMS', 'CISCO SYSTEMS', 'CISCO SYSTEMS', 'CISCO SYSTEMS',
#        'CITIGROUP', 'CITIGROUP', 'CITIGROUP', 'CITIGROUP', 'CITIGROUP',
#        'CITIGROUP', 'CITIGROUP', 'CITIGROUP', 'CITIGROUP', 'CITIGROUP',
#        'COCA COLA', 'COCA COLA', 'COCA COLA', 'COCA COLA', 'COCA COLA',
#        'COCA COLA', 'COCA COLA', 'COCA COLA', 'COCA COLA', 'COCA COLA',
#        'COLGATE-PALM', 'COLGATE-PALM', 'COLGATE-PALM', 'COLGATE-PALM',
#        'COLGATE-PALM', 'COLGATE-PALM', 'COLGATE-PALM', 'COLGATE-PALM',
#        'COLGATE-PALM', 'COLGATE-PALM', 'COMCAST A', 'COMCAST A',
#        'COMCAST A', 'COMCAST A', 'COMCAST A', 'COMCAST A', 'COMCAST A',
#        'COMCAST A', 'COMCAST A', 'COMCAST A', 'CONOCOPHILLIPS',
#        'CONOCOPHILLIPS', 'CONOCOPHILLIPS', 'CONOCOPHILLIPS',
#        'CONOCOPHILLIPS', 'CONOCOPHILLIPS', 'CONOCOPHILLIPS',
#        'CONOCOPHILLIPS', 'CONOCOPHILLIPS', 'CONOCOPHILLIPS',
#        'COSTCO WHOLESALE', 'COSTCO WHOLESALE', 'COSTCO WHOLESALE',
#        'COSTCO WHOLESALE', 'COSTCO WHOLESALE', 'COSTCO WHOLESALE',
#        'COSTCO WHOLESALE', 'COSTCO WHOLESALE', 'COSTCO WHOLESALE',
#        'COSTCO WHOLESALE', 'CVS HEALTH', 'CVS HEALTH', 'CVS HEALTH',
#        'CVS HEALTH', 'CVS HEALTH', 'CVS HEALTH', 'CVS HEALTH',
#        'CVS HEALTH', 'CVS HEALTH', 'CVS HEALTH', 'DANAHER', 'DANAHER',
#        'DANAHER', 'DANAHER', 'DANAHER', 'DANAHER', 'DANAHER', 'DANAHER',
#        'DANAHER', 'DANAHER', 'DUKE ENERGY', 'DUKE ENERGY', 'DUKE ENERGY',
#        'DUKE ENERGY', 'DUKE ENERGY', 'DUKE ENERGY', 'DUKE ENERGY',
#        'DUKE ENERGY', 'DUKE ENERGY', 'DUKE ENERGY', 'ELI LILLY',
#        'ELI LILLY', 'ELI LILLY', 'ELI LILLY', 'ELI LILLY', 'ELI LILLY',
#        'ELI LILLY', 'ELI LILLY', 'ELI LILLY', 'ELI LILLY',
#        'EMERSON ELECTRIC', 'EMERSON ELECTRIC', 'EMERSON ELECTRIC',
#        'EMERSON ELECTRIC', 'EMERSON ELECTRIC', 'EMERSON ELECTRIC',
#        'EMERSON ELECTRIC', 'EMERSON ELECTRIC', 'EMERSON ELECTRIC',
#        'EMERSON ELECTRIC', 'EXELON', 'EXELON', 'EXELON', 'EXELON',
#        'EXELON', 'EXELON', 'EXELON', 'EXELON', 'EXELON', 'EXELON',
#        'EXXON MOBIL', 'EXXON MOBIL', 'EXXON MOBIL', 'EXXON MOBIL',
#        'EXXON MOBIL', 'EXXON MOBIL', 'EXXON MOBIL', 'EXXON MOBIL',
#        'EXXON MOBIL', 'EXXON MOBIL', 'FACEBOOK CLASS A',
#        'FACEBOOK CLASS A', 'FACEBOOK CLASS A', 'FACEBOOK CLASS A',
#        'FACEBOOK CLASS A', 'FEDEX', 'FEDEX', 'FEDEX', 'FEDEX', 'FEDEX',
#        'FEDEX', 'FEDEX', 'FEDEX', 'FEDEX', 'FEDEX', 'FORD MOTOR',
#        'FORD MOTOR', 'FORD MOTOR', 'FORD MOTOR', 'FORD MOTOR',
#        'FORD MOTOR', 'FORD MOTOR', 'FORD MOTOR', 'FORD MOTOR',
#        'FORD MOTOR', 'GENERAL DYNAMICS', 'GENERAL DYNAMICS',
#        'GENERAL DYNAMICS', 'GENERAL DYNAMICS', 'GENERAL DYNAMICS',
#        'GENERAL DYNAMICS', 'GENERAL DYNAMICS', 'GENERAL DYNAMICS',
#        'GENERAL DYNAMICS', 'GENERAL DYNAMICS', 'GENERAL ELECTRIC',
#        'GENERAL ELECTRIC', 'GENERAL ELECTRIC', 'GENERAL ELECTRIC',
#        'GENERAL ELECTRIC', 'GENERAL ELECTRIC', 'GENERAL ELECTRIC',
#        'GENERAL ELECTRIC', 'GENERAL ELECTRIC', 'GENERAL ELECTRIC',
#        'GENERAL MOTORS', 'GENERAL MOTORS', 'GENERAL MOTORS',
#        'GENERAL MOTORS', 'GENERAL MOTORS', 'GENERAL MOTORS',
#        'GENERAL MOTORS', 'GILEAD SCIENCES', 'GILEAD SCIENCES',
#        'GILEAD SCIENCES', 'GILEAD SCIENCES', 'GILEAD SCIENCES',
#        'GILEAD SCIENCES', 'GILEAD SCIENCES', 'GILEAD SCIENCES',
#        'GILEAD SCIENCES', 'GILEAD SCIENCES', 'GOLDMAN SACHS GP',
#        'GOLDMAN SACHS GP', 'GOLDMAN SACHS GP', 'GOLDMAN SACHS GP',
#        'GOLDMAN SACHS GP', 'GOLDMAN SACHS GP', 'GOLDMAN SACHS GP',
#        'GOLDMAN SACHS GP', 'GOLDMAN SACHS GP', 'GOLDMAN SACHS GP',
#        'HALLIBURTON', 'HALLIBURTON', 'HALLIBURTON', 'HALLIBURTON',
#        'HALLIBURTON', 'HALLIBURTON', 'HALLIBURTON', 'HALLIBURTON',
#        'HALLIBURTON', 'HALLIBURTON', 'HOME DEPOT', 'HOME DEPOT',
#        'HOME DEPOT', 'HOME DEPOT', 'HOME DEPOT', 'HOME DEPOT',
#        'HOME DEPOT', 'HOME DEPOT', 'HOME DEPOT', 'HOME DEPOT',
#        'HONEYWELL INTL', 'HONEYWELL INTL', 'HONEYWELL INTL',
#        'HONEYWELL INTL', 'HONEYWELL INTL', 'HONEYWELL INTL',
#        'HONEYWELL INTL', 'HONEYWELL INTL', 'HONEYWELL INTL',
#        'HONEYWELL INTL', 'INTEL', 'INTEL', 'INTEL', 'INTEL', 'INTEL',
#        'INTEL', 'INTEL', 'INTEL', 'INTEL', 'INTEL',
#        'INTERNATIONAL BUS.MCHS', 'INTERNATIONAL BUS.MCHS',
#        'INTERNATIONAL BUS.MCHS', 'INTERNATIONAL BUS.MCHS',
#        'INTERNATIONAL BUS.MCHS', 'INTERNATIONAL BUS.MCHS',
#        'INTERNATIONAL BUS.MCHS', 'INTERNATIONAL BUS.MCHS',
#        'INTERNATIONAL BUS.MCHS', 'INTERNATIONAL BUS.MCHS',
#        'JOHNSON & JOHNSON', 'JOHNSON & JOHNSON', 'JOHNSON & JOHNSON',
#        'JOHNSON & JOHNSON', 'JOHNSON & JOHNSON', 'JOHNSON & JOHNSON',
#        'JOHNSON & JOHNSON', 'JOHNSON & JOHNSON', 'JOHNSON & JOHNSON',
#        'JOHNSON & JOHNSON', 'JP MORGAN CHASE & CO',
#        'JP MORGAN CHASE & CO', 'JP MORGAN CHASE & CO',
#        'JP MORGAN CHASE & CO', 'JP MORGAN CHASE & CO',
#        'JP MORGAN CHASE & CO', 'JP MORGAN CHASE & CO',
#        'JP MORGAN CHASE & CO', 'JP MORGAN CHASE & CO',
#        'JP MORGAN CHASE & CO', 'KINDER MORGAN', 'KINDER MORGAN',
#        'KINDER MORGAN', 'KINDER MORGAN', 'KINDER MORGAN', 'KINDER MORGAN',
#        'KINDER MORGAN', 'KRAFT HEINZ', 'KRAFT HEINZ', 'LOCKHEED MARTIN',
#        'LOCKHEED MARTIN', 'LOCKHEED MARTIN', 'LOCKHEED MARTIN',
#        'LOCKHEED MARTIN', 'LOCKHEED MARTIN', 'LOCKHEED MARTIN',
#        'LOCKHEED MARTIN', 'LOCKHEED MARTIN', 'LOCKHEED MARTIN',
#        "LOWE'S COMPANIES", "LOWE'S COMPANIES", "LOWE'S COMPANIES",
#        "LOWE'S COMPANIES", "LOWE'S COMPANIES", "LOWE'S COMPANIES",
#        "LOWE'S COMPANIES", "LOWE'S COMPANIES", "LOWE'S COMPANIES",
#        "LOWE'S COMPANIES", 'MASTERCARD', 'MASTERCARD', 'MASTERCARD',
#        'MASTERCARD', 'MASTERCARD', 'MASTERCARD', 'MASTERCARD',
#        'MASTERCARD', 'MASTERCARD', 'MASTERCARD', 'MCDONALDS', 'MCDONALDS',
#        'MCDONALDS', 'MCDONALDS', 'MCDONALDS', 'MCDONALDS', 'MCDONALDS',
#        'MCDONALDS', 'MCDONALDS', 'MCDONALDS', 'MEDTRONIC', 'MEDTRONIC',
#        'MEDTRONIC', 'MERCK & COMPANY', 'MERCK & COMPANY',
#        'MERCK & COMPANY', 'MERCK & COMPANY', 'MERCK & COMPANY',
#        'MERCK & COMPANY', 'MERCK & COMPANY', 'MERCK & COMPANY',
#        'MERCK & COMPANY', 'MERCK & COMPANY', 'METLIFE', 'METLIFE',
#        'METLIFE', 'METLIFE', 'METLIFE', 'METLIFE', 'METLIFE', 'METLIFE',
#        'METLIFE', 'METLIFE', 'MICROSOFT', 'MICROSOFT', 'MICROSOFT',
#        'MICROSOFT', 'MICROSOFT', 'MICROSOFT', 'MICROSOFT', 'MICROSOFT',
#        'MICROSOFT', 'MICROSOFT', 'MONDELEZ INTERNATIONAL CL.A',
#        'MONDELEZ INTERNATIONAL CL.A', 'MONDELEZ INTERNATIONAL CL.A',
#        'MONDELEZ INTERNATIONAL CL.A', 'MONDELEZ INTERNATIONAL CL.A',
#        'MONDELEZ INTERNATIONAL CL.A', 'MONDELEZ INTERNATIONAL CL.A',
#        'MONDELEZ INTERNATIONAL CL.A', 'MONDELEZ INTERNATIONAL CL.A',
#        'MONDELEZ INTERNATIONAL CL.A', 'MORGAN STANLEY', 'MORGAN STANLEY',
#        'MORGAN STANLEY', 'MORGAN STANLEY', 'MORGAN STANLEY',
#        'MORGAN STANLEY', 'MORGAN STANLEY', 'MORGAN STANLEY',
#        'MORGAN STANLEY', 'MORGAN STANLEY', 'NETFLIX', 'NETFLIX',
#        'NETFLIX', 'NETFLIX', 'NETFLIX', 'NETFLIX', 'NETFLIX', 'NETFLIX',
#        'NETFLIX', 'NETFLIX', 'NEXTERA ENERGY', 'NEXTERA ENERGY',
#        'NEXTERA ENERGY', 'NEXTERA ENERGY', 'NEXTERA ENERGY',
#        'NEXTERA ENERGY', 'NEXTERA ENERGY', 'NEXTERA ENERGY',
#        'NEXTERA ENERGY', 'NEXTERA ENERGY', "NIKE 'B'", "NIKE 'B'",
#        "NIKE 'B'", "NIKE 'B'", "NIKE 'B'", "NIKE 'B'", "NIKE 'B'",
#        "NIKE 'B'", "NIKE 'B'", "NIKE 'B'", 'NVIDIA', 'NVIDIA', 'NVIDIA',
#        'NVIDIA', 'NVIDIA', 'NVIDIA', 'NVIDIA', 'NVIDIA', 'NVIDIA',
#        'NVIDIA', 'OCCIDENTAL PTL', 'OCCIDENTAL PTL', 'OCCIDENTAL PTL',
#        'OCCIDENTAL PTL', 'OCCIDENTAL PTL', 'OCCIDENTAL PTL',
#        'OCCIDENTAL PTL', 'OCCIDENTAL PTL', 'OCCIDENTAL PTL',
#        'OCCIDENTAL PTL', 'ORACLE', 'ORACLE', 'ORACLE', 'ORACLE', 'ORACLE',
#        'ORACLE', 'ORACLE', 'ORACLE', 'ORACLE', 'ORACLE',
#        'PAYPAL HOLDINGS', 'PAYPAL HOLDINGS', 'PEPSICO', 'PEPSICO',
#        'PEPSICO', 'PEPSICO', 'PEPSICO', 'PEPSICO', 'PEPSICO', 'PEPSICO',
#        'PEPSICO', 'PEPSICO', 'PFIZER', 'PFIZER', 'PFIZER', 'PFIZER',
#        'PFIZER', 'PFIZER', 'PFIZER', 'PFIZER', 'PFIZER', 'PFIZER',
#        'PHILIP MORRIS INTL', 'PHILIP MORRIS INTL', 'PHILIP MORRIS INTL',
#        'PHILIP MORRIS INTL', 'PHILIP MORRIS INTL', 'PHILIP MORRIS INTL',
#        'PHILIP MORRIS INTL', 'PHILIP MORRIS INTL', 'PHILIP MORRIS INTL',
#        'PROCTER & GAMBLE', 'PROCTER & GAMBLE', 'PROCTER & GAMBLE',
#        'PROCTER & GAMBLE', 'PROCTER & GAMBLE', 'PROCTER & GAMBLE',
#        'PROCTER & GAMBLE', 'PROCTER & GAMBLE', 'PROCTER & GAMBLE',
#        'PROCTER & GAMBLE', 'QUALCOMM', 'QUALCOMM', 'QUALCOMM', 'QUALCOMM',
#        'QUALCOMM', 'QUALCOMM', 'QUALCOMM', 'QUALCOMM', 'QUALCOMM',
#        'QUALCOMM', "RAYTHEON 'B'", "RAYTHEON 'B'", "RAYTHEON 'B'",
#        "RAYTHEON 'B'", "RAYTHEON 'B'", "RAYTHEON 'B'", "RAYTHEON 'B'",
#        "RAYTHEON 'B'", "RAYTHEON 'B'", "RAYTHEON 'B'", 'SCHLUMBERGER',
#        'SCHLUMBERGER', 'SCHLUMBERGER', 'SCHLUMBERGER', 'SCHLUMBERGER',
#        'SCHLUMBERGER', 'SCHLUMBERGER', 'SCHLUMBERGER', 'SCHLUMBERGER',
#        'SCHLUMBERGER', 'SIMON PROPERTY GROUP', 'SIMON PROPERTY GROUP',
#        'SIMON PROPERTY GROUP', 'SIMON PROPERTY GROUP',
#        'SIMON PROPERTY GROUP', 'SIMON PROPERTY GROUP',
#        'SIMON PROPERTY GROUP', 'SIMON PROPERTY GROUP',
#        'SIMON PROPERTY GROUP', 'SIMON PROPERTY GROUP', 'SOUTHERN',
#        'SOUTHERN', 'SOUTHERN', 'SOUTHERN', 'SOUTHERN', 'SOUTHERN',
#        'SOUTHERN', 'SOUTHERN', 'SOUTHERN', 'SOUTHERN', 'STARBUCKS',
#        'STARBUCKS', 'STARBUCKS', 'STARBUCKS', 'STARBUCKS', 'STARBUCKS',
#        'STARBUCKS', 'STARBUCKS', 'STARBUCKS', 'STARBUCKS', 'TARGET',
#        'TARGET', 'TARGET', 'TARGET', 'TARGET', 'TARGET', 'TARGET',
#        'TARGET', 'TARGET', 'TARGET', 'TEXAS INSTRUMENTS',
#        'TEXAS INSTRUMENTS', 'TEXAS INSTRUMENTS', 'TEXAS INSTRUMENTS',
#        'TEXAS INSTRUMENTS', 'TEXAS INSTRUMENTS', 'TEXAS INSTRUMENTS',
#        'TEXAS INSTRUMENTS', 'TEXAS INSTRUMENTS', 'TEXAS INSTRUMENTS',
#        'UNION PACIFIC', 'UNION PACIFIC', 'UNION PACIFIC', 'UNION PACIFIC',
#        'UNION PACIFIC', 'UNION PACIFIC', 'UNION PACIFIC', 'UNION PACIFIC',
#        'UNION PACIFIC', 'UNION PACIFIC', "UNITED PARCEL SER.'B'",
#        "UNITED PARCEL SER.'B'", "UNITED PARCEL SER.'B'",
#        "UNITED PARCEL SER.'B'", "UNITED PARCEL SER.'B'",
#        "UNITED PARCEL SER.'B'", "UNITED PARCEL SER.'B'",
#        "UNITED PARCEL SER.'B'", "UNITED PARCEL SER.'B'",
#        "UNITED PARCEL SER.'B'", 'UNITED TECHNOLOGIES',
#        'UNITED TECHNOLOGIES', 'UNITED TECHNOLOGIES',
#        'UNITED TECHNOLOGIES', 'UNITED TECHNOLOGIES',
#        'UNITED TECHNOLOGIES', 'UNITED TECHNOLOGIES',
#        'UNITED TECHNOLOGIES', 'UNITED TECHNOLOGIES',
#        'UNITED TECHNOLOGIES', 'UNITEDHEALTH GROUP', 'UNITEDHEALTH GROUP',
#        'UNITEDHEALTH GROUP', 'UNITEDHEALTH GROUP', 'UNITEDHEALTH GROUP',
#        'UNITEDHEALTH GROUP', 'UNITEDHEALTH GROUP', 'UNITEDHEALTH GROUP',
#        'UNITEDHEALTH GROUP', 'UNITEDHEALTH GROUP', 'US BANCORP',
#        'US BANCORP', 'US BANCORP', 'US BANCORP', 'US BANCORP',
#        'US BANCORP', 'US BANCORP', 'US BANCORP', 'US BANCORP',
#        'US BANCORP', 'VERIZON COMMUNICATIONS', 'VERIZON COMMUNICATIONS',
#        'VERIZON COMMUNICATIONS', 'VERIZON COMMUNICATIONS',
#        'VERIZON COMMUNICATIONS', 'VERIZON COMMUNICATIONS',
#        'VERIZON COMMUNICATIONS', 'VERIZON COMMUNICATIONS',
#        'VERIZON COMMUNICATIONS', 'VERIZON COMMUNICATIONS', "VISA 'A'",
#        "VISA 'A'", "VISA 'A'", "VISA 'A'", "VISA 'A'", "VISA 'A'",
#        "VISA 'A'", "VISA 'A'", "VISA 'A'", "VISA 'A'",
#        'WALGREENS BOOTS ALLIANCE', 'WALGREENS BOOTS ALLIANCE',
#        'WALGREENS BOOTS ALLIANCE', 'WALMART', 'WALMART', 'WALMART',
#        'WALMART', 'WALMART', 'WALMART', 'WALMART', 'WALMART', 'WALMART',
#        'WALMART', 'WALT DISNEY', 'WALT DISNEY', 'WALT DISNEY',
#        'WALT DISNEY', 'WALT DISNEY', 'WALT DISNEY', 'WALT DISNEY',
#        'WALT DISNEY', 'WALT DISNEY', 'WALT DISNEY', 'WELLS FARGO & CO',
#        'WELLS FARGO & CO', 'WELLS FARGO & CO', 'WELLS FARGO & CO',
#        'WELLS FARGO & CO', 'WELLS FARGO & CO', 'WELLS FARGO & CO',
#        'WELLS FARGO & CO', 'WELLS FARGO & CO', 'WELLS FARGO & CO'],
#       dtype=object)

# %% [markdown]
# Training model and making prediction

# %%
linear_regressor = LinearRegression()
linear_regressor.fit(np.array(X_train.reshape(-1, 1)), y_train.reshape(-1, 1))

y_predict = linear_regressor.predict(X_test.reshape(-1, 1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-0b2c343ddd15> in <module>()
#       1 linear_regressor = LinearRegression()
# ----> 2 linear_regressor.fit(np.array(X_train.reshape(-1, 1)), y_train.reshape(-1, 1))
#       3
#       4 y_predict = linear_regressor.predict(X_test.reshape(-1, 1))
#
# /home/programs/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# /home/programs/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     762         _assert_all_finite(y)
#     763     if y_numeric and y.dtype.kind == 'O':
# --> 764         y = y.astype(np.float64)
#     765
#     766     check_consistent_length(X, y)
#
# ValueError: could not convert string to float: 'ORACLE'

# %%
# Plot points and fit line for training data
plt.scatter(X_train, y_train, color='teal', edgecolors='black', label='Training-set observation points')
plt.plot(X_train.reshape(-1, 1), linear_regressor.predict(X_train.reshape(-1, 1)), color='grey', label='Fit Regression Line')
plt.title('Salary vs Experience')
plt.xlabel('Experience (in years)')
plt.ylabel('Salary (in USD)')

# plot scatter points and line for test data
plt.scatter(X_test, y_test, color='red', edgecolors='black', label='Test-set observation points')
plt.legend()
plt.show()

# %% [markdown]
# <h1>2. Multivarite Linear Regression</h1>

# %% [markdown]
# Import libraries

# %%
# We already have imported LinearRegression in above algorithm, going to use the same
import statsmodels.formula.api as sm

# %% [markdown]
# Extracting training and test dataset

# %%
dataset = pd.read_csv('../input/m-50-startups/50_Startups.csv')

X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# Handle categorical variable - State column
labelencoder_X = LabelEncoder()
X[:,3] = labelencoder_X.fit_transform(X[:, 3])
hotonencoder_X = OneHotEncoder(categorical_features = [3])
X = hotonencoder_X.fit_transform(X).toarray()

# Avoiding the dummy trap
X = X[:, 1:]

# We are going to keep 20% of the dataset in test dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/5, random_state=0)

# %% [markdown]
# Algorithm execution

# %%
multiple_linear_regressor = LinearRegression()
multiple_linear_regressor.fit(X_train, y_train)

# y_pred contains all the values predicted by trained model
y_pred = multiple_linear_regressor.predict(X_test)

# %% [markdown]
# *  <h2> Backward Elimination for model optimization</h2>

# %% [markdown]
# Our current model is not optimal, since we don't know the impact of every predictor (or feature) on target variable. So we are going to use Backward Elimanation technique to make it optimal by removing insignificant predictors.

# %%
# adding const X0 at the very start of matrix
X = np.append(arr=np.ones((50, 1)).astype(int), values=X, axis=1)

# %%
# Starting Backword Elimination Steps
# Step 1 - Taking all the predictors(features) in X_opt. Our X_opt will contain only most optimal predictors. We will keep optimizing it
X_opt = X[:, [0, 1, 2, 3, 4, 5]]
# Step 2 - fitting the full model with all predictors
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
# Step 3 - analysing & fetching the predictor with value more than 0.05 
regressor_OLS.summary()
# Step 4 - removing the predictor [In this case column with index 2]
X_opt = X[:, [0, 1, 3, 4, 5]]
# Step 5 - Re-fit the model with removed predictor
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()

### Repeating 3, 4, 5 till we don't get all the predictor with Significant level < 0.5
# Removed 2nd index column and done fitting.

# Step 3 - analysing & fetching the predictor with value more than 0.05 
regressor_OLS.summary()
# Step 4 - removing the predictor [In this case column with index 1]
X_opt = X[:, [0, 3, 4, 5]]
# Step 5 - Re-fit the model with removed predictor
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
# Removed 1st index column and done fitting.

# Step 3 - analysing & fetching the predictor with value more than 0.05 
regressor_OLS.summary()
# Step 4 - removing the predictor [In this case column with index 4]
X_opt = X[:, [0, 3, 5]]
# Step 5 - Re-fit the model with removed predictor
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
# Removed 4th index column and done fitting.

# Step 3 - analysing & fetching the predictor with value more than 0.05 
regressor_OLS.summary()
# Step 4 - removing the predictor [In this case column with index 5]
X_opt = X[:, [0, 3]]
# Step 5 - Re-fit the model with removed predictor
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
# Removed 5th index column and done fitting.
regressor_OLS.summary()

# FINISHED

# %% [markdown]
# Now all predictors are below 0.05 significant level and our model is optimized as per Backward Elimination

# %% [markdown]
# <h1>3. Polynomial Regression</h1>

# %% [markdown]
# Import algorithm specific modules

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
dataset = pd.read_csv('../input/polynomial-position-salary-data/Position_Salaries.csv')

X = dataset.iloc[:,1:2].values
y = dataset.iloc[:,-1].values

# We don't have enough record in our dataset, so we are going to skip the step of spliting our X, y into test and train dataset

# %% [markdown]
# From here. we are simply generating the matrix for X^0, X^1 and X^2

# %%
poly_reg = PolynomialFeatures(degree = 2)
X_poly = poly_reg.fit_transform(X)

# %%
# linear regression model
linear_reg_model = LinearRegression()
linear_reg_model.fit(X, y)

# polynomial regression model
poly_reg_model = LinearRegression()
poly_reg_model.fit(X_poly, y)

# %% [markdown]
# We have trained both models linear and polynomial. Now we are going to compare the plots of both models

# %%
plt.scatter(X, y, color='red', label='Actual observation points')
plt.plot(X, linear_reg_model.predict(X), label='Linear regressor fit curve')
plt.plot(X, poly_reg_model.predict(poly_reg.fit_transform(X)), label='Polynmial regressor fit line')
plt.title('Truth or bluff (Linear Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')

plt.legend()
plt.show()

# %% [markdown]
# <h1>4. Simple Vector Regression (SVR)</h1>

# %% [markdown]
# Import model specific libraries

# %%
from sklearn.svm import SVR

# %%
dataset = pd.read_csv('../input/polynomial-position-salary-data/Position_Salaries.csv')

X = dataset.iloc[:,1:2].values
y = dataset.iloc[:,-1].values

# %% [markdown]
# Performing feature scaling, since it is not an inbuild feature of SVR class in sk-learn

# %%
scale_X = StandardScaler()
scale_y = StandardScaler()

X = scale_X.fit_transform(X)
y = scale_y.fit_transform(y.reshape(-1, 1))

# %% [markdown]
# Algorithm execution

# %%
svr_regressor = SVR(kernel='rbf', gamma='auto')
svr_regressor.fit(X, y)

# %% [markdown]
# Visualizing the SVR predictions

# %%
plt.scatter(X, y, color='red', label='Actual observation points')
plt.plot(X, svr_regressor.predict(X), label='SVR regressor')
plt.title('Truth or bluff (SVR Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')

plt.legend()
plt.show()

# %% [markdown]
# Predicting salary for someone who has 6.5 years of experience.

# %%
scale_y.inverse_transform(svr_regressor.predict(scale_X.transform(np.array([[6.5]]))))

# %% [markdown]
# <h1>5. Decision Tree - Regression</h1>

# %% [markdown]
# Algorithm specific imports

# %%
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# Read dataset and extract feature and target variable from that.

# %%
dataset = pd.read_csv('../input/polynomial-position-salary-data/Position_Salaries.csv')

X = dataset.iloc[:, 1:2].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# No need to perform feature scaling. Since it will get taken care by the library itself.

# %% [markdown]
# Creating regressor

# %%
tree_regressor = DecisionTreeRegressor(random_state = 0)
tree_regressor.fit(X, y)

# %% [markdown]
# Visualizing the graph

# %%
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape(len(X_grid), 1)

plt.scatter(X, y, color='red', label='Actual observation points')
plt.plot(X_grid, tree_regressor.predict(X_grid), label='Tree regressor')
plt.title('Truth or bluff (Tree Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')

plt.legend()
plt.show()

# %% [markdown]
# Predicting salary for someone who has 6.5 years of experience.

# %%
tree_regressor.predict([[6.5]])

# %% [markdown]
# Here we are not getting the good prediction, may be because of 2D plain (or single feature). It should give better predictions for 3d plan.

# %% [markdown]
# <h1>6. Random Forest Regression</h1>

# %% [markdown]
# Algorithm specific imports

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
dataset = pd.read_csv('../input/polynomial-position-salary-data/Position_Salaries.csv')

X = dataset.iloc[:, 1:2].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# Regressor creation

# %%
forest_regressor = RandomForestRegressor(n_estimators = 300, random_state = 0)
forest_regressor.fit(X, y)

# %% [markdown]
# Plot and visualize graph

# %%
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape(len(X_grid), 1)

plt.scatter(X, y, color='red', label='Actual observation points')
plt.plot(X_grid, forest_regressor.predict(X_grid), label='Random Forest regressor')
plt.title('Truth or bluff (Random Forest Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')

plt.legend()
plt.show()

# %% [markdown]
# Predict salary for 6.5 year experienced employee, we are taking same value of x so that we can compare the predicted value form Polynomial's and Decision Tree's prediction

# %%
forest_regressor.predict([[6.5]])

# %% [markdown]
# This prediction is much better than the ones obtained from other regression algorithms

# %%
Will keep refining these implementations and visualizations.
